# %% [markdown]
# Naive Bayes algorithms are a set of supervised statistical classification machine learning algorithms based on the **Bayes probability theorem**.
# <br>
#
# Bayes theorem states that:
# <br>
#
# P(A|B) = P(B|A) * P(A)/P(B)
# <br>
#
# An important assumption made by Bayes theorem is that **the value of a particular feature is independent from the value of any other feature for a given the class**.
# <br>
#
# I have done a sentiment analysis on the [Reddit dataset](https://www.kaggle.com/cosmos98/twitter-and-reddit-sentimental-analysis-dataset), which is a multiclass classification problem.

# %% [markdown]
# ### About the dataset used:
#
# It consists of two columns: `category` and `clean_comment`.
#
# Category column:
#
# *  1 : Indicating a Postive Sentiment
# *  0 : Indicating it is a Neutral Sentiment
# * -1 : Indicating a Negative Sentiment
#
# Comment column:
#
# These comments were made on political leaders as well as people's opinion towards the next prime minister of the Nation(in context with General Elections Held In India 2019).

# %% [markdown]
# ### Basic workflow of building the classifier:
#
# (From each comment, build a vocabulary that consists of word, it's sentiment and it's frequency.
# For any given string, it's sentiment is decided by multiplying the probability of each word occuring)
#
# * Step 1: Calculate the prior probability for each class labels
# * Step 2: Find likelihood probability with each attribute for each class
# * Step 3: Put these value in Bayes Formula and calculate posterior probability
# * Step 4: See which class has a higher probability, given the input belongs to the higher probability class.

# %% [markdown]
# # Table of contents
#
#
# 1. Loading the dataset
# <br>
#
# 2. Analysis
# <br>
#
# 3. Modelling
# <br>
#
# 4. Evaluative results
# <br>
#
# 5. Future scope

# %% [markdown]
# ## Part 1: Loading the dataset

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

import re

import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# import functions from helper.py
from helper import clean_text,find_freq,word_sentiment

# %% [markdown]
# The helper function(helper.py) consists of the following functions:
#
# 1. `clean_text` : The very first step in predict the sentiment of a given string(here, comments) is to tokenize it, i.e, represent it in a list of individual words present in the string. Also, words that don't add much meaning to the string can be removed(stop words) and the remaining words can be stemmed to generate the root words. To achieve this, in-built functions from **NLTK** have been used.
#
#
# 2. `find_freq` : We need to find frequency of each word occuring in the given dataset, this frequency is later used in the formula to compare it's occurences in different classes.
#
#
# 3. `word_sentiment` : This function gives the positive, negative and neutral words in the vocabulary that we built.

# %%
# Load stop words and function for stemming the data

stop_words = stopwords.words('english')
stemmer=PorterStemmer()

# %%
# Load the data

data=pd.read_csv("Reddit_Data.csv")

# %% [markdown]
# ## Part 2: Analysis

# %%
data.head()
# Out:
#                                        clean_comment  category
# 0   family mormon have never tried explain them t...         1
# 1  buddhism has very much lot compatible with chr...         1
# 2  seriously don say thing first all they won get...        -1
# 3  what you have learned yours and only yours wha...         0
# 4  for your own benefit you may want read living ...         1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37249 entries, 0 to 37248
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clean_comment  37149 non-null  object
#  1   category       37249 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 582.1+ KB

# %% [markdown]
# There are 100 categories, which don't have corresponding comment, we drop those rows.

# %%
data=data.dropna()

# %%
data.head()
# Out:
#                                        clean_comment  category
# 0   family mormon have never tried explain them t...         1
# 1  buddhism has very much lot compatible with chr...         1
# 2  seriously don say thing first all they won get...        -1
# 3  what you have learned yours and only yours wha...         0
# 4  for your own benefit you may want read living ...         1

# %%
data.shape
# Out:
# (37149, 2)

# %%
data['category'].value_counts()
# Out:
#  1    15830
#  0    13042
# -1     8277
# Name: category, dtype: int64

# %% [raw]
# This can be used in case of binary classification:
#
# data = data[data.category!=0]

# %%
# positive sentiment

data.loc[data['category']==1, 'clean_comment'].iloc[0]
# Out:
# ' family mormon have never tried explain them they still stare puzzled from time time like some kind strange creature nonetheless they have come admire for the patience calmness equanimity acceptance and compassion have developed all the things buddhism teaches '

# %%
# neutral sentiment

data.loc[data['category']==0, 'clean_comment'].iloc[0]
# Out:
# 'what you have learned yours and only yours what you want teach different focus the goal not the wrapping paper buddhism can passed others without word about the buddha '

# %%
# negative sentiment

data.loc[data['category']==-1, 'clean_comment'].iloc[0]
# Out:
# 'seriously don say thing first all they won get its too complex explain normal people anyway and they are dogmatic then doesn matter what you say see mechante post and for any reason you decide later life move from buddhism and that doesn suit you identity though you still get keep all the wisdom then your family will treat you like you went through weird hippy phase for while there didncha and you never hear the end pro tip don put one these your wall jpg '

# %% [markdown]
# An observation that can be made about the text is that it doesn't contain **capital letters** and punctuations or **user handles**.

# %% [markdown]
# Unlike most of the models, naive bayes doesn't require encoding of y(here,category) variable, since it deals with discrete distribution.

# %% [markdown]
# ## Part 3: Modelling

# %%
# splitting the data into train and validation set

X_train,X_val,y_train,y_val=train_test_split(data['clean_comment'],data['category'],test_size=0.2,
                                             stratify=data['category'],shuffle=True)

# %%
X_train.head()
# Out:
# 27885    please read his statement not praising pakista...
# 5416     invito tutti non dimenticarsi non considerare ...
# 21627     cia files doesn tell much about the veracity ...
# 31980    instead improving existing lines and facilitie...
# 18942    another one his useless whining and blame game...
# Name: clean_comment, dtype: object

# %% [markdown]
# The training data consists strings.
# <br>
# Given a string, the vocabulary returns a pair of tuple (word,string):frequency.
# For example, consider a list of strings
# <br>`["it's  beautiful day", "life is beautiful"]`.
#
# <br>The vocabulary would return
# the following key valie pairs:
# `{("beautiful",1):2 ("life",1):1 ("day",1):1}`

# %%
def vocabulary(voc,comments,ys):
    '''
    Input:
        voc: existing vocabulary 
        comments: the dataset containing comments
        ys: the label corresponding to each comment
    Output:
        voc: updated vocabulary(a dictionary containing (word,label) as the key 
                                and it's corresponding frequency as value)
        
        It is of the format : {(word,label):frequency}
    '''
    for y,comm in zip(ys,comments):
        # clean and tokenize each comm by passing through the helper function
        for word in clean_text(comm, stop_words, stemmer):
            pair=(word,y)
            
            # if pair already exists in vocabulary, increase frequency by 1
            if pair in voc:
                voc[pair]+=1
                
            #if the word is occuring for the first time, set the frequency to 1
            else:
                voc[pair]=1
    return voc

# %%
# get the vocabulary by passing training dataset

vocab=vocabulary({}, X_train, y_train)

# %%
vocab
# Out:
# {('pleas', 0): 152,
#  ('read', 0): 93,
#  ('statement', 0): 30,
#  ('prais', 0): 13,
#  ('pakistan', 0): 139,
#  ('appreci', 0): 7,
#  ('attack', 0): 65,
#  ('simpli', 0): 10,
#  ('said', 0): 130,
#  ('blame', 0): 37,
#  ('whole', 0): 6,
#  ('countri', 0): 103,
#  ('peopl', 0): 311,
#  ('invito', 0): 1,
#  ('tutti', 0): 16,
#  ('non', 0): 151,
#  ('dimenticarsi', 0): 1,
#  ('considerar', 0): 2,
#  ('itali', 0): 9,
#  ('una', 0): 38,
#  ('commun', 0): 42,
#  ('miglior', 0): 3,
#  ('dell', 0): 28,
#  ('altr', 0): 2,
#  ('dei', 0): 15,
#  ('buoni', 0): 1,
#  ('picchi', 0): 1,
#  ('localizzati', 0): 1,
#  ('discussioni', 0): 3,
#  ('produtt', 0): 1,
#  ('siamo', 0): 3,
#  ('mezzo', 0): 3,
#  ('gent', 0): 8,
#  ('che', 0): 180,
#  ('nemmeno', 0): 2,
#  ('usar', 0): 4,
#  ('downvot', 0): 26,
#  ('porco', 0): 1,
#  ('dio', 0): 1,
#  ('reddit', 0): 54,
#  ('cazzo', 0): 11,
#  ('regol', 0): 2,
#  ('diecimila', 0): 1,
#  ('edit', 0): 61,
#  ('sono', 0): 48,
#  ('incazzato', 0): 1,
#  ('perchè', 0): 6,
#  ('ospedal', 0): 1,
#  ('giorni', 0): 4,
#  ('mangio', 0): 1,
#  ('cia', 1): 17,
#  ('file', 1): 75,
#  ('tell', 1): 259,
#  ('much', 1): 1081,
#  ('verac', 1): 5,
#  ('info', 1): 65,
#  ('seem', 1): 503,
#  ('unlik', 1): 70,
#  ('bare', 1): 43,
#  ('one', 1): 1972,
#  ('year', 1): 1122,
#  ('unban', 1): 4,
#  ('second', 1): 166,
#  ('time', 1): 1437,
#  ('old', 1): 319,
#  ('rss', 1): 229,
#  ('would', 1): 1739,
#  ('hold', 1): 167,
#  ('clout', 1): 11,
#  ('relev', 1): 85,
#  ('enough', 1): 299,
#  ('read', 1): 454,
#  ('origin', 1): 149,
#  ('sourc', 1): 280,
#  ('rdp', 1): 1,
#  ('82', 1): 1,
#  ('00457r005000450005', 1): 1,
#  ('pdf', 1): 20,
#  ('noth', 1): 331,
#  ('research', 1): 86,
#  ('guess', 1): 159,
#  ('instead', 1): 248,
#  ('improv', 1): 161,
#  ('exist', 1): 207,
#  ('line', 1): 224,
#  ('facil', 1): 17,
#  ('build', 1): 207,
#  ('new', 1): 796,
#  ('anoth', -1): 179,
#  ('one', -1): 851,
#  ('useless', -1): 43,
#  ('whine', -1): 10,
#  ('blame', -1): 105,
#  ('game', -1): 218,
#  ('congress', -1): 522,
#  ('lol', -1): 25,
#  ('fuck', -1): 1053,
#  ('ff', -1): 9,
#  ('stop', -1): 191,
#  ('shit', -1): 528,
#  ('talk', -1): 227,
#  ('predecessor', -1): 2,
#  ('older', -1): 7,
#  ('govt', -1): 191,
#  ('expect', -1): 131,
#  ('leader', -1): 196,
#  ('nation', -1): 357,
#  ('level', -1): 103,
#  ('immatur', -1): 9,
#  ('damn', -1): 45,
#  ('high', -1): 84,
#  ('loop', 1): 12,
#  ('someon', 1): 425,
#  ('explain', 1): 109,
#  ('give', 1): 687,
#  ('link', 1): 225,
#  ('whole', 1): 298,
#  ('rafael', 1): 6,
#  ('fiasco', 1): 20,
#  ('infect', 0): 2,
#  ('clear', 0): 2,
#  ('bottom', 0): 11,
#  ('haryanvi', -1): 2,
#  ('guy', -1): 351,
#  ('live', -1): 214,
#  ('half', -1): 80,
#  ('life', -1): 147,
#  ('abroad', -1): 14,
#  ('ama', -1): 15,
#  ('let', 1): 588,
#  ('predict', 1): 95,
#  ('2019', 1): 184,
#  ('india', 1): 2719,
#  ('alway', 1): 387,
#  ('continu', 1): 195,
#  ('shit', 1): 332,
#  ('post', 1): 831,
#  ('fear', 1): 111,
#  ('increas', 1): 196,
#  ('facebook', 1): 106,
#  ('instagram', 1): 17,
#  ('like', 1): 2664,
#  ('loos', 1): 41,
#  ('bollywood', 1): 162,
#  ('star', 1): 39,
#  ('bjp', 1): 2349,
#  ('win', 1): 697,
#  ('thump', 1): 20,
#  ('major', 1): 504,
#  ('recess', 1): 10,
#  ('market', 1): 175,
#  ('stay', 1): 124,
#  ('strong', 1): 215,
#  ('elect', 1): 964,
#  ('sacr', 1): 23,
#  ('game', 1): 255,
#  ('season', 1): 57,
#  ('good', 1): 2437,
#  ('petrol', 1): 23,
#  ('price', 1): 151,
#  ('around', 1): 333,
#  ('add', 1): 132,
#  ('later', 1): 128,
#  ('momo', -1): 2,
#  ('fool', -1): 25,
#  ('around', -1): 147,
#  ('everyon', -1): 191,
#  ('sana', -1): 1,
#  ('day', -1): 339,
#  ('well', 1): 953,
#  ('soon', 1): 121,
#  ('light', 1): 115,
#  ('inform', 1): 217,
#  ('cell', 1): 77,
#  ('churn', 1): 8,
#  ('stuff', 1): 203,
#  ('jawaharl', 1): 3,
#  ('nehru', 1): 80,
#  ('incestu', 1): 1,
#  ('tendenc', 1): 17,
#  ('love', 0): 21,
#  ('pictur', 0): 27,
#  ('unfortun', 0): 3,
#  ('like', 0): 517,
#  ('see', 0): 175,
#  ('smile', 0): 6,
#  ('mean', -1): 298,
#  ('alway', -1): 189,
#  ('year', -1): 407,
#  ('rule', -1): 159,
#  ('whenev', -1): 16,
#  ('ask', -1): 223,
#  ('seriou', -1): 111,
#  ('question', -1): 221,
#  ('serious', -1): 143,
#  ('think', -1): 527,
#  ('develop', -1): 144,
#  ('occur', -1): 8,
#  ('within', -1): 64,
#  ('modi', -1): 1058,
#  ('indian', -1): 558,
#  ('toilet', -1): 63,
#  ('road', -1): 63,
#  ('make', -1): 490,
#  ('imagin', -1): 50,
#  ('defec', -1): 4,
#  ('open', -1): 73,
#  ('travel', -1): 42,
#  ('foot', -1): 14,
#  ('pre', -1): 24,
#  ('2014', -1): 69,
#  ('call', 0): 117,
#  ('savag', 0): 7,
#  ('kick', 0): 11,
#  ('everi', 0): 75,
#  ('muslim', 0): 89,
#  ('bastard', 0): 6,
#  ('ask', 0): 96,
#  ('articl', -1): 170,
#  ('ever', -1): 118,
#  ('name', -1): 161,
#  ('crimin', -1): 70,
#  ('politician', -1): 175,
#  ('didnt', -1): 14,
#  ('self', -1): 36,
#  ('goal', -1): 16,
#  ('block', -1): 52,
#  ('black', -1): 116,
#  ('news', -1): 374,
#  ('confus', -1): 41,
#  ('narr', -1): 28,
#  ('said', -1): 382,
#  ('use', -1): 407,
#  ('get', -1): 857,
#  ('earlier', -1): 41,
#  ('700r', -1): 1,
#  ('dont', -1): 71,
#  ('know', -1): 488,
#  ('group', -1): 136,
#  ('incom', -1): 16,
#  ('person', -1): 252,
#  ('compar', -1): 65,
#  ('even', -1): 685,
#  ('fabric', -1): 13,
#  ('could', -1): 203,
#  ('give', -1): 291,
#  ('credibl', -1): 16,
#  ('free', -1): 47,
#  ('media', -1): 400,
#  ('danger', -1): 56,
#  ('still', -1): 297,
#  ('democraci', -1): 94,
#  ('hey', 1): 75,
#  ('hear', 1): 138,
#  ('pleas', 1): 383,
#  ('assur', 1): 20,
#  ('parent', 1): 141,
#  ('realli', 1): 936,
#  ('mean', 1): 446,
#  ('person', 1): 551,
#  ('believ', 1): 464,
#  ('peopl', 1): 2900,
#  ('heavili', 1): 44,
#  ('bias', 1): 70,
#  ('due', 1): 174,
#  ('news', 1): 488,
#  ('channel', 1): 167,
#  ('caustic', 1): 1,
#  ('languag', 1): 166,
#  ('vitriol', 1): 2,
#  ('vibe', 1): 11,
#  ('grip', 1): 8,
#  ('countri', 1): 1236,
#  ('howev', 1): 197,
#  ('also', 1): 1167,
#  ('fall', 1): 115,
#  ('extrem', 1): 163,
#  ('pacifist', 1): 1,
#  ('narr', 1): 94,
#  ('either', 1): 238,
#  ('pakistan', 1): 642,
#  ('rogu', 1): 4,
#  ('state', 1): 947,
#  ('openli', 1): 54,
#  ('support', 1): 786,
#  ('terror', 1): 162,
#  ('eventu', 1): 54,
#  ('flee', 1): 6,
#  ('written', 1): 91,
#  ('depth', 1): 23,
#  ('hatr', 1): 55,
#  ('toward', 1): 217,
#  ('immedi', 1): 74,
#  ('peac', 1): 175,
#  ('jestur', 1): 1,
#  ('foreign', 1): 130,
#  ('minist', 1): 454,
#  ('say', 1): 1164,
#  ('blindli', 1): 21,
#  ('oppos', 1): 119,
#  ('propos', 1): 33,
#  ('oic', 1): 8,
#  ('benefit', 1): 157,
#  ('anoth', 1): 375,
#  ('claim', 1): 281,
#  ('pulawama', 1): 1,
#  ('attack', 1): 363,
#  ('act', 1): 221,
#  ('reveng', 1): 23,
#  ('pull', 1): 77,
#  ('wool', 1): 2,
#  ('eye', 1): 94,
#  ('interest', 1): 337,
#  ('reason', 1): 412,
#  ('distanc', 1): 17,
#  ('rememb', 1): 199,
#  ('osama', 1): 10,
#  ('bin', 1): 7,
#  ('laden', 1): 7,
#  ('want', 1): 1129,
#  ('earth', 1): 51,
#  ('hide', 1): 41,
#  ('right', 1): 1312,
#  ('next', 1): 372,
#  ('huge', 1): 261,
#  ('militari', 1): 94,
#  ('complex', 1): 38,
#  ('captur', 1): 38,
#  ('covert', 1): 9,
#  ('forget', 1): 115,
#  ('tonn', 1): 1,
#  ('materi', 1): 54,
#  ('avail', 1): 92,
#  ('humbl', 1): 10,
#  ('urg', 1): 35,
#  ('reli', 1): 23,
#  ('show', 1): 531,
#  ('proof', 1): 110,
#  ('comment', 1): 421,
#  ('reddit', 1): 186,
#  ('certainli', 1): 58,
#  ('prioriti', 1): 35,
#  ('nation', 1): 797,
#  ('cannot', 1): 184,
#  ('weak', 1): 82,
#  ('everi', 1): 580,
#  ('depend', 1): 81,
#  ('courag', 1): 26,
#  ('citizen', 1): 157,
#  ('respond', 1): 47,
#  ('need', 1): 1067,
#  ('love', 1): 592,
#  ('otherwis', 1): 80,
#  ('first', 1): 753,
#  ('use', 1): 1096,
#  ('servic', 1): 134,
#  ('intellig', 1): 75,
#  ('final', 1): 160,
#  ('understand', 1): 366,
#  ('propon', 1): 4,
#  ('individu', 1): 97,
#  ('almost', 1): 182,
#  ('soldier', 1): 53,
#  ('seen', 1): 289,
#  ('imagin', 1): 111,
#  ('classmat', 1): 3,
#  ('aggress', 1): 38,
#  ('talk', 1): 481,
#  ('stake', 1): 19,
#  ('higher', 1): 89,
#  ('mani', 1): 952,
#  ('practic', 1): 153,
#  ('violenc', 1): 133,
#  ('verbal', 1): 6,
#  ('physic', 1): 56,
#  ('come', 1): 881,
#  ('frankli', 1): 22,
#  ('way', 1): 910,
#  ('round', 1): 36,
#  ('chill', 1): 23,
#  ('enjoy', 1): 144,
#  ('life', 1): 291,
#  ('highli', 1): 68,
#  ('recommend', 1): 71,
#  ('watch', 1): 271,
#  ('get', 1): 1910,
#  ('upset', 1): 119,
#  ('curiou', -1): 33,
#  ('accept', -1): 69,
#  ('money', -1): 246,
#  ('peddl', -1): 5,
#  ('lie', -1): 89,
#  ('never', 0): 105,
#  ('take', 0): 109,
#  ('stand', 0): 38,
#  ('rathe', 1): 10,
#  ('jpg', 1): 78,
#  ('go', 1): 685,
#  ('reeeee', 1): 1,
#  ('fact', 1): 377,
#  ('basic', 1): 188,
#  ('moslem', 1): 1,
#  ('vote', 1): 970,
#  ('mass', 1): 113,
#  ('cong', 1): 47,
#  ('secular', 1): 139,
#  ('ask', 1): 514,
#  ('hindu', 1): 688,
#  ('commun', 1): 404,
#  ('bigotri', 1): 16,
#  ('perhap', -1): 13,
#  ('spent', -1): 48,
#  ('time', -1): 579,
#  ('librari', -1): 22,
#  ('would', -1): 632,
#  ('understand', -1): 136,
#  ('look', 1): 829,
#  ('fine', 1): 156,
#  ('global', 1): 82,
#  ('warm', 1): 26,
#  ('ass', 1): 78,
#  ('glad', 1): 82,
#  ('potenti', 1): 63,
#  ('crop', 1): 26,
#  ('hope', 1): 517,
#  ('king', 1): 52,
#  ('jong', 1): 6,
#  ('bozo', -1): 1,
#  ('destroy', -1): 62,
#  ('thing', -1): 600,
#  ('creat', -1): 118,
#  ('entir', -1): 109,
#  ('problem', 1): 399,
#  ('1947', 1): 31,
#  ('thing', 1): 1229,
#  ('delhi', 1): 324,
#  ('poison', 1): 19,
#  ('smog', 1): 5,
#  ('union', 1): 43,
#  ('ministri', 1): 47,
#  ('sit', 1): 106,
#  ('mention', 1): 173,
#  ('edit', 1): 312,
#  ('ad', 1): 135,
#  ('phrase', 1): 12,
#  ('want', 0): 176,
#  ('remain', 0): 12,
#  ('silent', 0): 8,
#  ('start', 0): 144,
#  ('piss', 0): 7,
#  ('friend', 0): 33,
#  ('famili', 0): 50,
#  ('whatsapp', 0): 34,
#  ('group', 0): 44,
#  ('ye', 0): 83,
#  ('siachen', 0): 4,
#  ('hamara', 0): 4,
#  ('jawan', 0): 8,
#  ('aap', 0): 110,
#  ('alreadi', 0): 68,
#  ('announc', 0): 28,
#  ('candid', 0): 34,
#  ('six', 0): 5,
#  ('seat', 0): 71,
#  ('respect', 0): 34,
#  ('bigot', 0): 6,
#  ('make', 0): 206,
#  ('anti', 0): 121,
#  ('nation', 0): 121,
#  ('amit', 1): 83,
#  ('shah', 1): 142,
#  ('skill', 1): 69,
#  ('gonna', 1): 116,
#  ('put', 1): 385,
#  ('test', 1): 98,
#  ('congress', 1): 1043,
#  ('readi', 1): 101,
#  ('sure', 1): 525,
#  ('anyth', 1): 403,
#  ('halt', 1): 8,
#  ('juggernaut', 1): 5,
#  ('salt', 1): 15,
#  ('harvest', 1): 6,
#  ('twitter', 1): 143,
#  ('tonight', 1): 14,
#  ('randia', -1): 38,
#  ('bad', -1): 443,
#  ('place', -1): 148,
#  ('discuss', -1): 78,
#  ('anyth', -1): 203,
#  ('toler', -1): 26,
#  ('scum', -1): 23,
#  ('hate', -1): 427,
#  ('anti', -1): 203,
#  ('piec', -1): 44,
#  ('differ', -1): 200,
#  ('come', -1): 385,
#  ('changer', -1): 2,
#  ('elimin', -1): 14,
#  ('petti', -1): 9,
#  ('corrupt', -1): 241,
#  ('add', -1): 45,
#  ('gargantuan', -1): 1,
#  ('number', -1): 113,
#  ('take', -1): 388,
#  ('mnrega', -1): 1,
#  ('good', -1): 208,
#  ('scheme', -1): 57,
#  ('long', -1): 211,
#  ('reach', -1): 54,
#  ('target', -1): 62,
#  ('asset', -1): 15,
#  ('creation', -1): 7,
#  ('happen', -1): 320,
#  ('paral', -1): 1,
#  ('variou', -1): 21,
#  ('studi', -1): 37,
#  ('estim', -1): 8,
#  ('alloc', -1): 9,
#  ('intend', -1): 8,
#  ('audienc', -1): 14,
#  ('rest', -1): 55,
#  ('swallow', -1): 4,
#  ('along', -1): 31,
#  ('way', -1): 350,
#  ('wors', -1): 100,
#  ('pd', -1): 2,
#  ('state', -1): 399,
#  ('govern', -1): 553,
#  ('neta', -1): 10,
#  ('babu', -1): 9,
#  ('also', -1): 430,
#  ('act', -1): 138,
#  ('allot', -1): 2,
#  ('aid', -1): 15,
#  ('poor', -1): 152,
#  ('plan', -1): 103,
#  ('panel', -1): 6,
#  ('recent', -1): 66,
#  ('found', -1): 59,
#  ('pais', -1): 2,
#  ('rupe', -1): 33,
#  ('montek', -1): 1,
#  ('singh', -1): 68,
#  ('ahluwalia', -1): 1,
#  ('cm', -1): 32,
#  ('pmjdi', -1): 1,
#  ('leakag', -1): 2,
#  ('plagu', -1): 10,
#  ('everi', -1): 249,
#  ('singl', -1): 124,
#  ('sinc', -1): 176,
#  ('nehru', -1): 39,
#  ('launch', -1): 27,
#  ('poverti', -1): 15,
#  ('allevi', -1): 1,
#  ('paisa', -1): 2,
#  ('rajiv', -1): 5,
#  ('gandhi', -1): 116,
#  ('fix', -1): 43,
#  ('quit', -1): 91,
#  ('liter', -1): 69,
#  ('indefinit', 0): 3,
#  ('semi', 0): 2,
#  ('protect', 0): 16,
#  ('persist', 0): 1,
#  ('vandal', 0): 2,
#  ('page', 0): 44,
#  ('subject', 0): 2,
#  ('request', 0): 14,
#  ('rightlog', 1): 1,
#  ('lol', 1): 375,
#  ('unbias', 1): 21,
#  ('think', 0): 286,
#  ('liber', 0): 35,
#  ('congress', 0): 260,
#  ('option', 0): 23,
#  ('would', 0): 195,
#  ('hesit', 0): 1,
#  ('classifi', 0): 34,
#  ('posit', 0): 18,
#  ('opposit', 0): 38,
#  ('bjp', 0): 529,
#  ('rss', 0): 47,
#  ('view', 0): 22,
#  ('run', 0): 62,
#  ('without', 0): 49,
#  ('choic', 0): 15,
#  ('expert', -1): 13,
#  ('fail', -1): 123,
#  ('gaug', -1): 1,
#  ('sentiment', -1): 28,
#  ('say', -1): 596,
#  ('aprtyashit', -1): 1,
#  ('jeet', -1): 1,
#  ('brief', 1): 26,
#  ('overview', 1): 5,
#  ('main', 1): 150,
#  ('achiev', 1): 141,
#  ('failur', 1): 51,
#  ('see', 1): 1105,
#  ('focus', 1): 57,
#  ('econom', 1): 196,
#  ('vision', 1): 56,
#  ('posit', 1): 198,
#  ('backlog', 1): 3,
#  ('road', 1): 174,
#  ('rail', 1): 17,
#  ('power', 1): 701,
#  ('project', 1): 224,
#  ('clear', 1): 183,
#  ('movement', 1): 70,
#  ('infrastructur', 1): 86,
#  ('turn', 1): 285,
#  ('forcapit', 1): 1,
#  ('sector', 1): 88,
#  ('1896181', 1): 1,
#  ('html', 1): 159,
#  ('ground', 1): 104,
#  ('raghuram', 1): 3,
#  ('rajan', 1): 15,
#  ('jaitley', 1): 46,
#  ('togeth', 1): 132,
#  ('succeed', 1): 18,
#  ('inflat', 1): 46,
#  ('target', 1): 116,
#  ('fiscal', 1): 18,
#  ('cutback', 1): 1,
#  ('make', 1): 1461,
#  ('credibl', 1): 53,
#  ('stabl', 1): 17,
#  ('boe', 1): 7,
#  ('decid', 1): 133,
#  ('2bn', 1): 1,
#  ('factori', 1): 22,
#  ('auto', 1): 22,
#  ('even', 1): 1478,
#  ('dalian', 1): 1,
#  ('wanda', 1): 1,
#  ('foxconn', 1): 1,
#  ('take', 1): 892,
#  ('infra', 1): 23,
#  ('bring', 1): 215,
#  ('job', 1): 403,
#  ('month', 1): 208,
#  ('mahindra', 1): 1,
#  ('tata', 1): 9,
#  ('relianc', 1): 37,
#  ('big', 1): 338,
#  ('domest', 1): 29,
#  ('corp', 1): 4,
#  ('start', 1): 626,
#  ('invest', 1): 109,
#  ('wave', 1): 62,
#  ('motor', 1): 9,
#  ('battl', 1): 33,
#  ('tank', 1): 13,
#  ('11507100082', 1): 1,
#  ('4', 1): 15,
#  ('defens', 1): 54,
#  ('jv', 1): 1,
#  ('aircraft', 1): 61,
#  ('ship', 1): 46,
#  ('significantli', 1): 17,
#  ('better', 1): 851,
#  ('100', 1): 158,
#  ('indigen', 1): 9,
#  ('product', 1): 129,
#  ('yet', 1): 227,
#  ('china', 1): 203,
#  ('still', 1): 691,
#  ('russian', 1): 18,
#  ('engin', 1): 71,
#  ('long', 1): 447,
#  ('top', 1): 343,
#  ('swacch', 1): 9,
#  ('bharat', 1): 78,
#  ('abhiyan', 1): 6,
#  ('made', 1): 512,
#  ('cleanli', 1): 19,
#  ('part', 1): 382,
#  ('convers', 1): 61,
#  ('railway', 1): 39,
#  ('org', 1): 14,
#  ('maintain', 1): 55,
#  ('premis', 1): 11,
#  ('result', 1): 327,
#  ('metro', 1): 59,
#  ('smaller', 1): 29,
#  ('place', 1): 420,
#  ('toilet', 1): 34,
#  ('rural', 1): 68,
#  ('acceler', 1): 6,
#  ('compar', 1): 169,
#  ('upa', 1): 169,
#  ('standard', 1): 102,
#  ('live', 1): 560,
#  ('neg', 1): 82,
#  ('bank', 1): 273,
#  ('privat', 1): 69,
#  ('compani', 1): 185,
#  ('stress', 1): 24,
#  ('bad', 1): 215,
#  ('debt', 1): 14,
#  ('last', 1): 439,
#  ('decad', 1): 120,
#  ('corpor', 1): 78,
#  ('profit', 1): 45,
#  ('moribund', 1): 2,
#  ('quarter', 1): 19,
#  ('public', 1): 324,
#  ('recapit', 1): 1,
#  ('nda', 1): 94,
#  ('address', 1): 99,
#  ('effect', 1): 164,
#  ('growth', 1): 112,
#  ('keep', 1): 481,
#  ('constrain', 1): 2,
#  ('futur', 1): 188,
#  ('farmer', 1): 86,
#  ('hurt', 1): 66,
#  ('two', 1): 404,
#  ('spend', 1): 133,
#  ('stagnat', 1): 5,
#  ('govern', 1): 1109,
#  ('scale', 1): 58,
#  ('back', 1): 575,
#  ('wast', 1): 67,
#  ('subsidi', 1): 41,
#  ('encourag', 1): 53,
#  ('danger', 1): 45,
#  ('cultiv', 1): 18,
#  ('habit', 1): 14,
#  ('borewel', 1): 1,
#  ('irrig', 1): 9,
#  ('monsoon', 1): 6,
#  ('fail', 1): 121,
#  ('insur', 1): 42,
#  ('fast', 1): 92,
#  ('intervent', 1): 9,
#  ('wait', 1): 212,
#  ('suicid', 1): 28,
#  ('could', 1): 609,
#  ('pass', 1): 136,
#  ('key', 1): 62,
#  ('structur', 1): 36,
#  ('reform', 1): 108,
#  ('gst', 1): 106,
#  ('land', 1): 187,
#  ('amend', 1): 30,
#  ('dismantl', 1): 3,
#  ('apmc', 1): 1,
#  ('solv', 1): 56,
#  ('food', 1): 121,
#  ('perman', 1): 45,
#  ('modi', 1): 2292,
#  ('spent', 1): 69,
#  ('polit', 1): 925,
#  ('capit', 1): 77,
#  ('defend', 1): 66,
#  ('sushma', 1): 19,
#  ('raje', 1): 5,
#  ('chouhan', 1): 5,
#  ('vyapam', 1): 14,
#  ('beef', 1): 103,
#  ('ban', 1): 234,
#  ('compulsori', 1): 9,
#  ('yoga', 1): 25,
#  ('variou', 1): 71,
#  ('hindutva', 1): 103,
#  ('retard', 1): 26,
#  ('earn', 1): 57,
#  ('trust', 1): 111,
#  ('investor', 1): 8,
#  ('deeper', 1): 18,
#  ('harder', 1): 27,
#  ('polic', 1): 177,
#  ('judiciari', 1): 21,
#  ('fund', 1): 171,
#  ('cbi', 1): 35,
#  ('freedom', 1): 139,
#  ('whistleblow', 1): 2,
#  ('protect', 1): 92,
#  ('shown', 1): 50,
#  ('indic', 1): 54,
#  ('happen', 1): 640,
#  ('art', 1): 41,
#  ('therapi', 1): 2,
#  ('sectiontak', 1): 1,
#  ('away', 1): 237,
#  ('commi', 1): 15,
#  ('lucki', 1): 38,
#  ('fun', 1): 149,
#  ('age', 1): 107,
#  ('goddamn', 0): 5,
#  ('final', 0): 64,
#  ('get', 0): 322,
#  ('evid', 0): 21,
#  ('background', 0): 6,
#  ('shut', 0): 10,
#  ('cheap', 1): 79,
#  ('crass', 1): 10,
#  ('unkil', 1): 14,
#  ('absolut', 1): 201,
#  ('class', 1): 219,
#  ('question', 1): 538,
#  ('wrong', 1): 228,
#  ('mandir', 1): 58,
#  ('issu', 1): 569,
#  ('uneduc', 1): 22,
#  ('villag', 1): 113,
#  ('probabl', 1): 285,
#  ('dont', 1): 167,
#  ('modern', 1): 69,
#  ('progress', 1): 117,
#  ('clean', 1): 168,
#  ('think', 1): 1463,
#  ('develop', 1): 401,
#  ('religi', 1): 184,
#  ('bull', 1): 10,
#  ('expect', 1): 279,
#  ('muslim', 1): 763,
#  ('free', 1): 885,
#  ('less', 1): 237,
#  ('opinion', 1): 279,
#  ('among', 1): 121,
#  ('friend', 1): 256,
#  ('user', 1): 118,
#  ('agre', 1): 227,
#  ('answer', 1): 190,
#  ('vote', 0): 212,
#  ('kanaka', 0): 1,
#  ('jpg', 0): 61,
#  ('cut', 0): 23,
#  ('india', -1): 1069,
#  ('player', -1): 26,
#  ('saw', -1): 60,
#  ('fan', -1): 52,
#  ('frustrat', -1): 36,
#  ('pointless', -1): 8,
#  ('indvsl', -1): 1,
#  ('increas', -1): 86,
#  ('interest', -1): 75,
#  ('chess', -1): 9,
#  ('root', 1): 48,
#  ('rule', 1): 277,
#  ('law', 1): 266,
#  ('serious', 1): 99,
#  ('rich', 1): 113,
#  ('connect', 1): 98,
#  ('outcom', 1): 32,
#  ('impun', 1): 7,
#  ('celebr', 1): 74,
#  ('proudli', 1): 12,
#  ('lot', 1): 690,
#  ('indian', 1): 1316,
#  ('societi', 1): 170,
#  ('fundament', 1): 45,
#  ('scam', 1): 95,
#  ('corporar', 1): 1,
#  ('takeov', 1): 3,
#  ('polici', 1): 275,
#  ('someth', 1): 553,
#  ('american', 1): 160,
#  ('context', 1): 67,
#  ('play', 1): 366,
#  ('necessarili', 1): 30,
#  ('repres', 1): 75,
#  ('2222', 1): 1,
#  ('baba', 1): 23,
#  ('ramdev', 1): 11,
#  ('mobil', 1): 57,
#  ('phone', 1): 97,
#  ('haridwar', 1): 1,
#  ('hardwar', 1): 12,
#  ('ecolog', 1): 5,
#  ('friendli', 1): 46,
#  ('swadeshi', 1): 2,
#  ('tamil', -1): 77,
#  ('chip', -1): 4,
#  ('shoulder', -1): 3,
#  ('ago', -1): 82,
#  ('doordarshan', -1): 4,
#  ('channel', -1): 73,
#  ('region', -1): 37,
#  ('variant', -1): 2,
#  ('exist', -1): 59,
#  ('three', -1): 38,
#  ('minut', -1): 26,
#  ('slot', -1): 5,
#  ('english', -1): 59,
#  ('hindi', -1): 53,
#  ('local', -1): 60,
#  ('languag', -1): 51,
#  ('relay', -1): 1,
#  ('station', -1): 30,
#  ('broadcast', -1): 4,
#  ('chennai', -1): 13,
#  ('last', -1): 155,
#  ('insist', -1): 8,
#  ('instead', -1): 101,
#  ('itt', 0): 15,
#  ('saliv', 0): 1,
#  ('randian', 0): 13,
#  ('putin', 0): 13,
#  ('man', 0): 137,
#  ('done', 0): 82,
#  ('earn', 0): 7,
#  ('affect', 0): 10,
#  ('know', 0): 185,
#  ('sign', 1): 97,
#  ('upcom', 1): 21,
#  ('economi', 1): 208,
#  ('mitron', 0): 19,
#  ('let', 0): 119,
#  ('chanda', 0): 1,
#  ('begin', 0): 18,
#  ('websit', 0): 29,
#  ('open', 0): 35,
#  ('anybodi', 0): 18,
#  ('els', 0): 39,
#  ('katrina', 0): 3,
#  ('kaif', 0): 1,
#  ('even', 0): 171,
#  ('speak', 0): 44,
#  ('hindi', 0): 140,
#  ('properli', 0): 4,
#  ('defin', 0): 4,
#  ('construct', 0): 9,
#  ('work', 0): 112,
#  ('book', 1): 155,
#  ('hindi', 1): 169,
#  ('guy', 0): 192,
#  ('left', 0): 59,
#  ('ganja', 0): 2,
#  ('non', -1): 194,
#  ('perform', -1): 32,
#  ('given', -1): 98,
#  ('loan', -1): 71,
#  ('waiver', -1): 18,
#  ('kid', -1): 65,
#  ('time', 0): 314,
#  ('travel', 0): 23,
#  ('senior', 1): 37,
#  ('chander', 1): 1,
#  ('prakash', 1): 11,
#  ('ganga', 1): 17,
#  ('chowdhri', 1): 1,
#  ('lal', 1): 5,
#  ('singh', 1): 155,
#  ('swoop', 1): 3,
#  ('hiranagar', 1): 1,
#  ('meet', 1): 108,
#  ('describ', 1): 43,
#  ('arrest', 1): 76,
#  ('crime', 1): 79,
#  ('branch', 1): 16,
#  ('jungl', 1): 7,
#  ('raj', 1): 35,
#  ('brand', 1): 80,
#  ('nomad', 1): 4,
#  ('pro', 1): 120,
#  ('parochi', 1): 2,
#  ('visibl', 1): 43,
#  ('sexist', 1): 6,
#  ('remark', 1): 36,
#  ('girl', 1): 159,
#  ('die', 1): 166,
#  ('day', 1): 693,
#  ('remain', 1): 120,
#  ('unnot', 1): 3,
#  ('high', 1): 314,
#  ('command', 1): 41,
#  ('campaign', 1): 195,
#  ('favour', 1): 40,
#  ('accus', 1): 75,
#  ('demand', 1): 71,
#  ('shift', 1): 50,
#  ('case', 1): 376,
#  ('jitendra', 1): 1,
#  ('echo', 1): 26,
#  ('asifa', 1): 11,
#  ('kathua', 1): 24,
#  ('rape', 1): 209,
#  ('fan', 1): 104,
#  ('option', 1): 144,
#  ('competit', 1): 44,
#  ('strict', 1): 20,
#  ('action', 1): 248,
#  ('corrupt', 1): 371,
#  ('requir', 1): 115,
#  ('know', 1): 1172,
#  ('hard', 1): 221,
#  ('remov', 1): 146,
#  ('court', 1): 179,
#  ('quickli', 1): 57,
#  ('speed', 1): 39,
#  ('attitud', 1): 46,
#  ('govt', 1): 377,
#  ('employe', 1): 32,
#  ...}

# %% [markdown]
# How does naive bayes predict classes?
#
# * The objective is to predict the probability of a string( which essentially contains words).
# * To do this, we calculate the probability of each string belonging to different classes, select the maximum and assign labels. This is given in (1).

# %% [markdown]
# $$P(pos|(w1,w2....wn)) = P(pos)*\prod_{i=1}^{n}P(w_{i}|pos)\tag{1} $$
# $$P(neutr|(w1,w2....wn)) = P(neutr)*\prod_{i=1}^{n}P(w_{i}|neutr) $$
# $$P(neg|(w1,w2....wn)) = P(neg)*\prod_{i=1}^{n}P(w_{i}|neg) $$
#
#
#
# $$parameters(pos) =P(W|pos) = \frac{freq_{pos} + \alpha}{N_{pos} + \alpha*V }\tag{2} $$
#
# $$parameters(neutr)= P(W|neutr) = \frac{freq_{neutr} + \alpha}{N_{neutr} + \alpha*V} $$
#
# $$parameters(neg)=P(W|neg) = \frac{freq_{neg} + \alpha}{N_{neg} + \alpha*V} $$
#
#
# where,
# 1. `P(pos|(w1,w2....wn))`: denotes the probability of given string being positive
# 2. `P(pos)`: probability of occurence of positive class
# 3. `P(w_i|pos)`(parameters_pos): denotes the probability of word i being positive, which is calculated by (2)
# 4. `N_pos`: total number of positive words for all comments in the dataset
# 5.  `freq_pos`: frequencies of that specific word in the positive
# 6. `alpha`: Laplacian smoothing parameter **(to avoid division by 0)**
# 7. `V`: length of vocabulary

# %%
# call the helper function to get a list of positive, neutral and negative words

pos_words= word_sentiment(vocab)[0]
neutr_words= word_sentiment(vocab)[1]
neg_words= word_sentiment(vocab)[2]

parameters_pos = {word:0 for word in pos_words}
parameters_neg = {word:0 for word in neg_words}
parameters_neutr = {word:0 for word in neutr_words}

# %%
len(parameters_pos)
# Out:
# 11424

# %%
len(parameters_neutr)
# Out:
# 15599

# %%
len(parameters_neg)
# Out:
# 8598

# %%
# find words in vocabulary and the length of the vocabulary

vocab_words=[key[0] for key in vocab.keys()]
vocab_len=len(vocab_words)

# %%
def naive_bayes(vocab,X_train,y_train,alpha=1):  
    '''
    Input:
        vocab: vocabulary containing word, label and its frequency
        X_train: dataset containing comments
        y_train: label corresponding to each comment
        alpha: Laplacian smoothing (deafult=1)
    Output:
        parameters_pos,parameters_neg,parameters_neutr: calculations corresponding to each sentiment
                                                        (see formula)
    '''
    
    num_pos=num_neg=num_neutr=0
    # store the total number of each sentiment
    
    for key in vocab.keys():
        # get N_pos, N_neutr, N_neg
        if key[1]==1:
            num_pos+=vocab.get(key,0)
        elif key[1]==0:
            num_neutr+=vocab.get(key,0)
        else:
            num_neg+=vocab.get(key,0)
    
    for word in vocab_words:
        #get frequency of word belonging to the three classes
        pos_freq=find_freq(vocab,word,1)
        neutr_freq=find_freq(vocab,word,0)
        neg_freq=find_freq(vocab,word,-1)
        
        # calculate parameters(see formula)
        prob_pos=(pos_freq+alpha)/(num_pos+vocab_len*alpha)
        prob_neutr=(neutr_freq+alpha)/(num_neutr+vocab_len*alpha)
        prob_neg=(neg_freq+alpha)/(num_neg+vocab_len*alpha)
        
        parameters_pos[word]=prob_pos
        parameters_neg[word]=prob_neg
        parameters_neutr[word]=prob_neutr
        
    return parameters_pos,parameters_neg,parameters_neutr

# %%
parameters_pos,parameters_neg,parameters_neutr=naive_bayes(vocab,X_train,y_train,1)

# %%
len(parameters_neutr)
# Out:
# 35621

# %%
parameters_pos
# Out:
# {'verac': 1.4605291984128915e-05,
#  'rdp': 4.868430661376305e-06,
#  '00457r005000450005': 4.868430661376305e-06,
#  'incestu': 4.868430661376305e-06,
#  'caustic': 4.868430661376305e-06,
#  'pacifist': 4.868430661376305e-06,
#  'jestur': 4.868430661376305e-06,
#  'pulawama': 4.868430661376305e-06,
#  'wool': 7.302645992064458e-06,
#  'tonn': 4.868430661376305e-06,
#  'moslem': 4.868430661376305e-06,
#  'rightlog': 4.868430661376305e-06,
#  'overview': 1.4605291984128915e-05,
#  'backlog': 9.73686132275261e-06,
#  'forcapit': 4.868430661376305e-06,
#  '1896181': 4.868430661376305e-06,
#  'cutback': 4.868430661376305e-06,
#  '2bn': 4.868430661376305e-06,
#  'dalian': 4.868430661376305e-06,
#  'wanda': 4.868430661376305e-06,
#  'foxconn': 4.868430661376305e-06,
#  '11507100082': 4.868430661376305e-06,
#  'jv': 4.868430661376305e-06,
#  'moribund': 7.302645992064458e-06,
#  'recapit': 4.868430661376305e-06,
#  'borewel': 4.868430661376305e-06,
#  'apmc': 4.868430661376305e-06,
#  'sectiontak': 4.868430661376305e-06,
#  'corporar': 4.868430661376305e-06,
#  '2222': 4.868430661376305e-06,
#  'haridwar': 4.868430661376305e-06,
#  'chander': 4.868430661376305e-06,
#  'chowdhri': 4.868430661376305e-06,
#  'swoop': 9.73686132275261e-06,
#  'balli': 4.868430661376305e-06,
#  'mandati': 4.868430661376305e-06,
#  'pensavo': 4.868430661376305e-06,
#  'fossero': 4.868430661376305e-06,
#  'moda': 7.302645992064458e-06,
#  'passeggera': 4.868430661376305e-06,
#  'dispatch': 7.302645992064458e-06,
#  'multirol': 4.868430661376305e-06,
#  '1000kg': 9.73686132275261e-06,
#  'glide': 4.868430661376305e-06,
#  'skew': 2.677636863756968e-05,
#  'evidenc': 1.4605291984128915e-05,
#  'kpi': 7.302645992064458e-06,
#  'bray': 9.73686132275261e-06,
#  'wyatt': 7.302645992064458e-06,
#  'jericho': 1.2171076653440764e-05,
#  'deobandi': 7.302645992064458e-06,
#  'ujjwala': 9.73686132275261e-06,
#  'preempt': 7.302645992064458e-06,
#  'peril': 7.302645992064458e-06,
#  'agrro': 4.868430661376305e-06,
#  'admittedli': 9.73686132275261e-06,
#  'nitesh': 7.302645992064458e-06,
#  'fingerfood': 4.868430661376305e-06,
#  'githubrepo': 4.868430661376305e-06,
#  'imm': 4.868430661376305e-06,
#  'adjustres': 4.868430661376305e-06,
#  'adjustpan': 4.868430661376305e-06,
#  'kbd': 4.868430661376305e-06,
#  'isvis': 4.868430661376305e-06,
#  'ishardwar': 4.868430661376305e-06,
#  'focusthisview': 4.868430661376305e-06,
#  'callbackwhenkbvis': 4.868430661376305e-06,
#  'callbackwhenkbgon': 4.868430661376305e-06,
#  'changebound': 4.868430661376305e-06,
#  'resiz': 4.868430661376305e-06,
#  'ballmer': 4.868430661376305e-06,
#  'attr': 4.868430661376305e-06,
#  'stackoverflow': 7.302645992064458e-06,
#  'bhat': 4.868430661376305e-06,
#  'dhongi': 4.868430661376305e-06,
#  'thirumavalavan': 4.868430661376305e-06,
#  'underpin': 9.73686132275261e-06,
#  'ccoleman': 4.868430661376305e-06,
#  'meredith': 7.302645992064458e-06,
#  'tampon': 4.868430661376305e-06,
#  'chorioamnion': 4.868430661376305e-06,
#  'miscarriag': 4.868430661376305e-06,
#  'ikora': 4.868430661376305e-06,
#  'kedarnath': 7.302645992064458e-06,
#  'saay': 4.868430661376305e-06,
#  'frost': 4.868430661376305e-06,
#  'zzz': 4.868430661376305e-06,
#  'prescenc': 7.302645992064458e-06,
#  'geotu': 1.4605291984128915e-05,
#  'carlson': 7.302645992064458e-06,
#  'silk': 7.302645992064458e-06,
#  'fad': 7.302645992064458e-06,
#  'bespok': 4.868430661376305e-06,
#  'are': 7.302645992064458e-06,
#  'etr': 4.868430661376305e-06,
#  'pegou': 4.868430661376305e-06,
#  'lembrando': 4.868430661376305e-06,
#  'feliz': 4.868430661376305e-06,
#  'espncricinfo': 4.868430661376305e-06,
#  'nqvucau': 4.868430661376305e-06,
#  '4ojohj1nxfpnyji': 4.868430661376305e-06,
#  'cocki': 1.4605291984128915e-05,
#  'unpopularopinion': 9.73686132275261e-06,
#  'calib': 1.2171076653440764e-05,
#  'bhajan': 9.73686132275261e-06,
#  'vapid': 4.868430661376305e-06,
#  'peepel': 4.868430661376305e-06,
#  'whera': 4.868430661376305e-06,
#  'tent': 7.302645992064458e-06,
#  ...}

# %%
# count the total number of each sentiment in the corpus 

pos_corpus=list(y_train).count(1)
neutr_corpus=list(y_train).count(0)
neg_corpus=list(y_train).count(-1)
total=pos_corpus+neg_corpus+neutr_corpus

# %% [markdown]
# The prior probability represents the underlying probability in the target population that a comment is positive, neutral or negative. In other words, if we had no specific information and blindly picked a comment out of the population set, what is the probability that it will belong to one specific class? That is the **"prior"**.
#
# $$P(C_{pos}) = \frac{C_{pos}}{C}{\tag3}$$
#
# Where,
# 1. `C_pos`: number of positive comments(pos_corpus)
# 2. `C`: total number of comments

# %%
# prior ratio calculation

prior_pos=pos_corpus/total
prior_neg=neg_corpus/total
prior_neutr=neutr_corpus/total

# %%
prior_pos
# Out:
# 0.42612470136949426

# %%
prior_neutr
# Out:
# 0.35105488071604024

# %%
prior_neg
# Out:
# 0.2228204179144655

# %%
def predict_NB(comment):
    '''
    Input:
        comment: a string containing text
    Output:
        prob_pos,prob_neg,prob_neutr: probability of the input belonging to the three sentiments
    '''
    list_word=clean_text(comment,stop_words,stemmer)
    #prob_pos=prob_neg=prob_neutr=0
    prob_pos=(prior_pos)
    prob_neg=(prior_neg)
    prob_neutr=(prior_neutr)
    for word in list_word:
        #since essentially all the dic contain the same keys
        if word in  list(parameters_pos.keys()):
            prob_pos*=(parameters_pos[word])
            prob_neg*=(parameters_neg[word])
            prob_neutr*=(parameters_neutr[word])
    return prob_pos,prob_neutr,prob_neg

# %% [markdown]
# ## Part 4: Evaluative results

# %% [markdown]
# ### Testing on random strings

# %%
predict_NB('i am an amazing person') # the probability is highest for positive
# Out:
# (2.160356740835329e-07, 7.497503502004981e-09, 1.8466471811660606e-08)

# %%
predict_NB('feeling sad today') # the probability is highest for negative
# Out:
# (7.932531609809585e-11, 1.9389737079007727e-12, 8.131147655872298e-11)

# %%
predict_NB("it's a beautiful day") # the probability is highest for positive
# Out:
# (1.5946139505693592e-07, 6.063198484230115e-09, 2.1271373515408036e-08)

# %%
# a wrong classification
predict_NB("terror attacks on the city") # the probability is highest for positive
# Out:
# (8.350993778286263e-11, 3.814340870886282e-12, 3.519484491498018e-11)

# %%
def test_NB(X_val,y_val):
    '''
    Input:
        X_val: dataset containing comments to be used for testing the model
        y_val: dataset containing labels to be used for testing the model
    Output:
        accuracy: accuracy of the model
    '''
    accuracy=0 #initialise accuracy to zero
    y_pred=[]  #prediction
    
    for comment in X_val:
        # get probabilities corresponding to each class
        pos,neg,neutr=predict_NB(comment)
        
        if(pos>neg) and (pos>neutr): # given comment is positive
            y_pred_i=1
        elif(neg>pos) and (neg>neutr): # given comment is negative
            y_pred_i=-1
        elif(neutr>neg) and (neutr>pos): # given comment is neutral
            y_pred_i=0
        y_pred.append(y_pred_i)
    
    # error is the mean of the differences between y_actual(y_val) and y_pred
    error=np.abs(np.mean(y_val-y_pred))
    accuracy=1-error
    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %(test_NB(X_val, y_val)))
# Out:
# Naive Bayes accuracy = 0.5845

# %% [markdown]
# The accuracy that we get is around 60%, which is good, since it's a basic model and it doesn't take into account the semantic relationship between words.

# %% [markdown]
# ## Part 5: Future scope

# %% [markdown]
# * Different smoothing methods can be tried( we have done Lalplacian, for which alpha=1, Lidstone smoothing, alpha<1)
# * Resampling of model due to skewed distribution of different classes

# %% [markdown]
# Resources used for theory and building the model:
# * https://towardsdatascience.com/introduction-to-na%C3%AFve-bayes-classifier-fa59e3e24aaf
# * https://www.kdnuggets.com/2020/07/spam-filter-python-naive-bayes-scratch.html
# * https://www.datacamp.com/community/tutorials/naive-bayes-scikit-learn
